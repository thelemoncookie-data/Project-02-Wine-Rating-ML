# %% [markdown]
# ### Darlene Phan
# August 11, 2022<br>
# Project 2

# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Data/wines_SPA.csv')
df.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %%
df.shape
# Out:
# (7500, 11)

# %% [markdown]
# NV stands for non vintage, which means that they are blends of multiple years. This does affect the price and possible rating of the wine. Since this doesn't fall in line with the other int in this column its best to drop so we don't have mixed data or create a bias<br>
# <br>
# Renaming year to vintage due to its bias. People associate year with price.

# %%
#Changing categorical values of N.V. to nan. 
df['year'] = df['year'].replace('N.V.', np.NaN)

# %%
#Changing year to vintage
dictionary = {'year': 'vintage'}
df = df.rename(columns=dictionary)

# %%
df.vintage.unique()
# Out:
# array(['2013', '2018', '2009', '1999', '1996', '1998', '2010', '1995',
#        '2015', '2011', '2016', '1970', '1946', '1962', '2019', '2004',
#        nan, '1931', '1979', '2005', '2020', '2014', '1985', '1929',
#        '2007', '2012', '2017', '2008', '2006', '2000', '2003', '2002',
#        '1991', '1994', '1990', '1989', '1987', '1986', '1981', '2001',
#        '1968', '1964', '1982', '1974', '1983', '1955', '1980', '1972',
#        '1953', '1958', '1942', '1965', '1992', '1973', '1997', '1967',
#        '1975', '1910', '1961', '1954', '1988', '1969', '1951', '1928',
#        '1976', '1949', '2021', '1959', '1922', '1978', '1925'],
#       dtype=object)

# %%
#checking and dropping duplicates
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
#checking for null/missing values
df.isnull().sum()
# Out:
# winery           0
# wine             0
# vintage         72
# rating           0
# num_reviews      0
# country          0
# region           0
# price            0
# type           106
# body           271
# acidity        271
# dtype: int64

# %% [markdown]
# Dropping missing values in vintage as discussed earlier. Dropping type, because that's not something should be imputed since it greatly impacts the possible rating of the wine.
#
# 'body' and 'acidity' will be handled differently

# %%
#Dropping missing values
df.dropna(subset=['type','vintage'], inplace=True)

# %%
#confirming 'type' and 'vintage' columns have been dropped
df.isnull().sum()
# Out:
# winery           0
# wine             0
# vintage          0
# rating           0
# num_reviews      0
# country          0
# region           0
# price            0
# type             0
# body           163
# acidity        163
# dtype: int64

# %%
#Correcting object type after dropping duplicates
df['vintage'] = df['vintage'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1877 entries, 0 to 6100
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       1877 non-null   object
#  1   wine         1877 non-null   object
#  2   vintage      1877 non-null   int64
#  3   rating       1877 non-null   float64
#  4   num_reviews  1877 non-null   int64
#  5   country      1877 non-null   object
#  6   region       1877 non-null   object
#  7   price        1877 non-null   float64
#  8   type         1877 non-null   object
#  9   body         1714 non-null   float64
#  10  acidity      1714 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 176.0+ KB

# %%
#Delete unnecessary colums
df = df.drop(columns=['num_reviews'])
df
# Out:
#                   winery             wine  vintage  rating country  \
# 0          Teso La Monja            Tinto     2013     4.9  Espana
# 1                 Artadi    Vina El Pison     2018     4.9  Espana
# 2           Vega Sicilia            Unico     2009     4.8  Espana
# 3           Vega Sicilia            Unico     1999     4.8  Espana
# 4           Vega Sicilia            Unico     1996     4.8  Espana
# ...                  ...              ...      ...     ...     ...
# 2046         Mustiguillo  Finca Terrerazo     2017     4.2  Espana
# 2047         Matarromera     Gran Reserva     2011     4.2  Espana
# 2048            Sei Solo         Preludio     2016     4.2  Espana
# 2049  Vinedos de Paganos       El Puntido     2005     4.2  Espana
# 6100   Remirez de Ganuza     Rioja Blanco     2017     4.2  Espana
#
#                 region   price                  type  body  acidity
# 0                 Toro  995.00              Toro Red   5.0      3.0
# ...

# %%
df.describe()
# Out:
#            vintage       rating        price         body      acidity
# count  1877.000000  1877.000000  1877.000000  1714.000000  1714.000000
# mean   2010.869473     4.404688   142.612586     4.263127     2.928238
# std      11.300344     0.148552   282.560181     0.660949     0.313328
# min    1910.000000     4.200000     6.260000     2.000000     1.000000
# 25%    2010.000000     4.300000    32.550000     4.000000     3.000000
# 50%    2015.000000     4.400000    55.140000     4.000000     3.000000
# 75%    2017.000000     4.500000   117.300000     5.000000     3.000000
# max    2021.000000     4.900000  3119.080000     5.000000     3.000000

# %%
#copy for machine learning
df_ml = df.copy()

# %% [markdown]
# Imputing mean for viz. Using this method because it makes more sense to fill it with an average to not skew the current data.

# %%
#imputing
df['body'] = df['body'].fillna(round(df['body'].mean()))
df['acidity'] = df['acidity'].fillna(round(df['acidity'].mean()))

# %% [markdown]
# ## Exploratory Data Viz
# Univariate visuals for the target and all features

# %%
#Visualizing the top 10 Wineries
plt.figure(figsize=(8, 6), dpi=80)
c=['darkmagenta', 'purple', 'darkviolet', 'darkorchid', 'mediumorchid','mediumpurple', 'orchid', 'violet', 'plum', 'thistle']
df.winery.value_counts().sort_values(ascending=False).head(10).plot(kind='pie', 
                                                                    autopct='%1.1f%%', 
                                                                    colors=c,
                                                                    fontsize=12)
plt.ylabel('')
plt.title('Top Ten Wineries', fontsize=14)
plt.show()

# %%
#top ten wines viz
plt.figure(figsize=(8, 6))
df.wine.value_counts(ascending=False).head(10).plot(kind='barh', width=.8, color=c)
plt.ylabel('')
plt.title('Top Ten Wines', fontsize=14)
plt.show()

# %% [markdown]
# Our first numerical column. Checking for outliers since vintage have a lot of different vintages

# %%
#Wine vintages outliers boxenplot
plt.figure(figsize=(6,8))
sns.set_style('whitegrid')
sns.boxenplot(data=df, y='vintage', color='purple')
plt.title("Wine Vintage's", fontsize=14)
plt.ylabel('Vintage', fontsize=13)
plt.show()

# %%
#lol, I'll be deleting this row. This was for my own amusement. 
#HOWEVER, 100% of the wines come from Spain. 
plt.figure(figsize=(8, 6))
df.country.value_counts().plot(kind='pie', autopct='%1.1f%%', fontsize=14, colors=c)
plt.ylabel(' ')
plt.title('Country of Origin', fontsize=15)
plt.show()

# %% [markdown]
# Interesting, turns out that the top regions for wine are taken up by 3 areas.

# %%
#Reigions bar plot
plt.figure(figsize=(8, 6))
df.region.value_counts().head(15).plot(kind='bar', color=c)
plt.title('Top 15 Regions', fontsize=14)
plt.show()

# %% [markdown]
# A deeper dive shows us that the lower 50% has less that 5 wines per reigon. Which means the top 3 are majority outliers. Curious as to how many unique wineries are in these locations and how many of them are mass produced.

# %%
#bottom 50% bar plot
plt.figure(figsize=(8, 6))
df.region.value_counts().tail(33).plot(kind='bar', color=c)
plt.title('Bottom 50% of Region', fontsize=14)
plt.show()

# %%
#Wine price distribution
fig, ax = plt.subplots(figsize=(8, 6))
n_bins = 33
ax.hist(df['price'], 
        n_bins, 
        color='purple',
        histtype ='bar')
plt.title('Distribution of Wine Price', fontsize=14)
ax.xaxis.set_major_formatter('${x:1.0f}')
plt.show()

# %% [markdown]
# Types of wine had the least categories out of all the categorical columns. I was able to plot all of them without it visually being overwhelming. Majority of the wines in this data set are red wines, hence the purplish color palette.

# %%
plt.figure(figsize=(8, 6))
df.type.value_counts().sort_values(ascending=True).plot(kind='barh', width=.8, color=c)
plt.title('Types of Wine by Count')
plt.show()

# %%
#Body rating distribution
plt.figure(figsize=(10,7))
sns.kdeplot(data=df, x="body", multiple='stack', color='purple', alpha=.7)
plt.title('Body Rating', fontsize=14)
plt.show()

# %%
#Acidity Distribution
plt.figure(figsize=(5,5))
df['acidity'].value_counts().plot(kind='bar', color='mediumpurple', width=.5)
plt.title('Acidity', fontsize=14)
plt.xlabel('Acidity Level', fontsize=13)
plt.xticks(rotation=0)
plt.ylabel('Number of Wines', fontsize=13)
plt.show()

# %% [markdown]
# ### The target

# %%
#Distribution of wine rating. 
sns.set_style('whitegrid')
plt.figure(figsize=(10,7))
sns.kdeplot(data=df, x="rating", multiple='stack', color='purple', alpha=.7)
plt.title('Rating Distribution', fontsize=14)
plt.show()

# %% [markdown]
# I have 15+ years of hospitality experience, and was able to correlate what I already knew about Spanish wines to these visuals. It was not surprising to find out that majority of Spanish wines have higher acidity levels(great for cutting through fatty foods), medium-full body (will hold up against food) and natrually very good mean rating between 4.3 - 4.7.
#
# Most wines are enjoyed with food. Since Spanish wines have characteristics that allow them to stand up to food and not be washed out, it's understandable why the majority of these ratings are as high as they are. I always knew, Spanish wines were great with food, I never realized that the majority of them had similar characteristics regardless of types or reigons. Situations like this is where my domain expertise will shine.
#
# Based on my background and visualizations, there are a couple different ways we could approach wine ratings. Since there are so many wine types, regions, on top of dropped rows that had missing wine types, there is always room for us to go back and create a more specific ML learning model. One that could be more focused on the regions of Spain or the types of wines. But for now, we will work on a ML model for the wines as a whole

# %%
large = 14
plt.rc('axes', labelsize=large)
f, axes = plt.subplots(1,4, figsize=(10,10))

ax1=sns.boxplot(y='rating', data=df, ax=axes[0], color='mediumpurple', width=.6)
axes[0].set_title('Wine Rating', fontsize=large)
plt.ylabel('')
sns.boxplot(y='price', data=df, ax=axes[1], color='darkorchid', width=.6)
axes[1].set_title('Wine Price', fontsize=large)

sns.boxplot(y='body', data=df, ax=axes[2], color='orchid', width=.6)
axes[2].set_title('Body Rating', fontsize=large)

sns.boxplot(y='acidity', data=df, ax=axes[3], color='mediumorchid', width=.6)
axes[3].set_title('Acidity Level', fontsize=large)

plt.suptitle('Other Numerical Outliers', fontsize=16)

#hide y axis label
for ax in axes.flat:
    ax.set(xlabel='', ylabel='')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Resubmit
# itendify outliers for all nummeric columns<br>
# Displayed above. <br>
# <b> Rating</b> : Outlier rating on the top end reaching 4.9<br>
# <b> Price</b> : Majority of wines fall within the 0-125 dollar range. Everything above 300 is an outlier. The range of pricing goes past the 3k mark but overall majoirty is within the 125 range.  <br>
# <b>Body</b> : Outlier low rating at 2.0.<br>
# <b>Acidity</b> :The reason there was not an indication previously for acidity having any outliers is because these would be considered as abnormal range. Acidity is ordinal encoded and have only 3 options (1,2,3) for acidity levels. Whereas price, has an infinate range. Determining outliers means that the points should be extremely high or extremely low data points relative to the nearest data point and the rest of the neighboring coexisting values. Acidity only has 3 steps. The outlier for price would be 2,900 from the average data point.

# %% [markdown]
# ### Multivariate EDA to identify any moderate or strong correlations

# %%
plt.figure(figsize=(10,8))
corr = df.corr()
matrix = np.triu(corr)
sns.heatmap(corr, annot=True, cmap=c)
plt.show()

# %%
#scatterplot
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.scatterplot(data=df, x='price', y='vintage', color='mediumorchid')
plt.gca().invert_yaxis()
ax.xaxis.set_major_formatter('${x:1.0f}')
plt.title('Wines by Price and Vintage', fontsize=15)
plt.show()

# %%
#scatterplot
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.scatterplot(data=df, x='price', y='rating', color='mediumpurple')
plt.gca().invert_yaxis()
ax.xaxis.set_major_formatter('${x:1.0f}')
plt.title('Wines by Rating and Price', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='rating', hue='acidity', color='purple')
plt.title('Wine Ratings & Acidity')
plt.show()

# %% [markdown]
# ### Project 2 part 3 Summary
# <b>Scatterplot</b> : To my surprise, I thought that the older wine vintages would have had higher price tags. Tunrs out that the higher priced wines were between 2000 - 2011. The ratings for the wines were still within 4.5-4.8, which was a fairly common range for the majority of the higher priced wines. I'm curious as to what the harvest was like during those years, because that could greatly affect the wine availability. Sometimes poor harvest years can lead to higher priced wines due to scarcity of quality wines that year.
# <br><br>
# <b>KDE Plot</b>: Demonstrates that regardless of rating, the majority had an acidity level of 3. However, there's still a fairly consistent distribution of lower/med acidic wines throughout the wine rating.

# %% [markdown]
# ## Resubmit

# %% [markdown]
# To Do:<br>
# There are a few fairly simple things you can do to better show your trends.<br><br>
#
# <b>1. Instead of the scatter plot to compare year and price, use a lineplot.  Whenever you have features that are changing over time, it's a great opportunity to use a lineplot to plot your data.  Your years would be the X axis and your line would represent the average price (or rating) for the wines in that year.  You would need to group your data by year and aggregate with either mean or median before plotting.</b><br>
#
# I apprecaite the feedback, but the idea was not to visualize wine price trends overtime. But rather to visualize how year and rating have no effect on what the wine prices are. I will go ahead and break this down into two simplified scatterplots<br><br>
# <b>
# 2. Also for the first plot, I think it would be easier to read if you chose one trend to focus on: Change in price or change in rating.  You could make 2 separate plots, one for each trend.  Another option, but one that's sometimes frowned on, is to create 2 y axes, one for rating and one for price and plot both lines on the same plot to compare how they change relative to each other.  It all depends on what trend you want to focus on: How does price change by year, how does rating change by year, or what is the relationship between price and rating and how does that relationship change over the years?</b><br>
#
# Will be broken into multiple plots. However, the learning platform states that we should be looking for correlations (and not trends) between targets/features or features/features. Similiarly to above, there aren't correlations to ratings in relation to years. <br><br>
# <b>
# 3. Your second plot is a distribution plot.  These are not great choices for analysis as they only describe your particular dataset, not any real trend in wines.  This is more appropriate for exploratory analysis.  What is a trend in relationships between features that you could explore?  Do you want to see how rating changes with acidity?  You could make a bar chart with acidity as the x axis and rating as the y-axis.</b><br>
# I agree, I just didn't want the plots to be repetitive and was limited since the LP specified we were not allowed to use histograms, boxplots or correlation plots. It's now a bar plot.
# <br><br><b>
# 4. Please create a correlation plot to help you explore correlations between your features.  This will help you get ideas for interesting plots, too.  It's great to focus on features that are more highly correlated with each other!</b><br>
# I agree with you, and I did this on my own. But the instructions on the learning platform specifically said not to use correlation plots so I did not include it. I was under the assumption they were not allowed. With that being said, wine vintage has the highest negative correlation with price. Please see image below.

# %%
from IPython.display import Image
Image("lp_screenshot.png")

# %% [markdown]
# Other thoughts:
# <b>1. I would drop the 'country' column.  it's all the same value so it doesn't add anything to the analysis or the modeling.</b><br>
# It will be dropped for the machine learning. I think it was a funny pie chart.<br><br>
#
# <b>2. If your analysis finds a linear relationship between year and rating, then you might keep year as numeric.  If your analysis finds that the rating fluctuates up and down between years, not really a straight line, you might consider one-hot encoding your years.<br></b>
# I didn't find a linear relationship between year and rating which is shown in the scatterplot and heatmap. This was also further explained in my markdown labeled project 2 part 3 summary. If I decide to keep this, I would consider using PCA since there are 70 different vintages.<br><br>
#
# <b>
# 3. An interesting question I have abour your dataset is about the relationship between the rating and the price?  I expect more expensive wines to have higher ratings, but is that true according to the data?  You could use a scatter or bar chart to explore this question."</b>
# <br>
#
# This feedback is confusing because originally I had a scatterplot displaying the relationship between rating, price and its correlation to year. And your first feedback was to change it to a lineplot. I also did a deeper explantion on how price doesn't have a direct correlation to rating or year. Seeing as how the 1920 bottle with a fairly high rating costs significantly less than a lot of other bottles regardless or rating or year.
# <br>
#
# I now have changed 'year' to 'vintage.' In my experience the word year has negative connotation to how wine is valued. Most people relate exepensive wine = year(aka how old the wine is), and that is certainly not true. People become very fixated on year rather than other attributes to what can contirube to a good wine, or in this case, good wine rating.
# <br>
#
# I'm a bit confused on this because a lot of the feedback was regarding the column price. The the overall goal of this project is to predict the rating of wines not the prices, which was outlined in my project propsal and was approved.

# %% [markdown]
# ### Just some fun interesting facts I wanted to include in my presentation but here is a sneak peek:
# Charles Shaw is an award winning winery from California. It's been nicknamed "Two Buck Chuck" because their bottles go for $2. There was also pushback from the wine community for a few years after the wine was awarded in 2002. Wine enthusiasts were not happy that a wine that costs only 2 dollars can have so many accolades and wanted to push the narrative that quality wines = higher price tags. <br><br>
# In recent years its become more widely accepted that the price of wine doesn't really matter. Wine production has changed drastically, from growing the grapes, harvesting, fermentation and even bottling. The same enthusiats who hate 2 Buck Chuck also hate screw top wines.

# %%
Image("2buckchuck.png")
